# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kjmazidi/Machine_Learning_3rd_edition/blob/master/Volume_II_Python/Part-I-Python/Chapter_2/pandas.ipynb)

# %% [markdown]
# # Pandas
#
# Pandas is a Python package providing fast, flexible data structures for data analysis. Read the docs and find installation instructions [here:](https://pandas.pydata.org/docs/)   https://pandas.pydata.org/docs/
#
#
# ### Code Accompanying ***The Machine Learning Handbooks***, Volume II, Chapter 2
#
# #### Book pdf is available on the GitHub repo: <https://github.com/kjmazidi/Machine_Learning_3rd_edition>
#
# ###### (c) 2025 KJG Mazidi, all rights reserved

# %% [markdown]
# # pandas data structures
#
# The primary data structure in pandas is the **DataFrame** which is arranged like a spreadsheet in rows and columns. Each row represents an observation in the dataset and each column is an attribute. Columns may be of different types. Rows and columns are labeled for fast access.
#
# Below we see how to create a data frame from a csv file and look at the first few rows.
#
# The entire data frame was read below. To read only certain columns, the usecols feature is helpful:
#
# ```
# df = pd.read_csv('name.csv', usecols=['colb', 'colx'])
# ```
#
# The following code assumes that the Heart csv file is in a folder named *data* one level up in the hierarchy, as it will be if you fork the repo.
#
# To read the csv file in Google colab, see notebook **colab** in the repo.

# %%
# imports used in this notebook
import pandas as pd

# %%
# read the file and look at the first few rows

df = pd.read_csv('../data/Heart.csv', index_col='ID')
df.head()
# Out:
#     Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# ID
# 1    63    1       typical     145   233    1        2    150      0      2.3
# 2    67    1  asymptomatic     160   286    0        2    108      1      1.5
# 3    67    1  asymptomatic     120   229    0        2    129      1      2.6
# 4    37    1    nonanginal     130   250    0        0    187      0      3.5
# 5    41    0    nontypical     130   204    0        2    172      0      1.4
#
#     Slope   Ca        Thal  AHD
# ID
# 1       3  0.0       fixed   No
# 2       2  3.0      normal  Yes
# 3       2  2.0  reversable  Yes
# 4       3  0.0      normal   No
# 5       1  0.0      normal   No

# %%
# pandas version in this notebook

pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# ### selecting
#
# The following demonstrates two different ways to index elements.

# %%
print(df['Age'][1]) # bracket notation
print(df.Age[1])    # use column attribute (has to be a valid Python identifier)
# Out:
# 63
# 63

# %% [markdown]
# ### loc and iloc accessors
#
# **loc** indexes using labels and **iloc** indexes using index positions
#
# Both specify the indices in row, col order.
#
# In the **loc** example we ask for the element with row label 1 and column label Age. In the **iloc** example we retrieve the same information using indices which start at 0.
#
# If the row position contains ':' then all rows will be selected, if the col position contains ':' then all columns will be selected.

# %%
df.loc[1, 'Age']  # row, col order
# Out:
# 63

# %%
df.loc[1:2, ['Age', 'Sex']]  # multiple row, multiple col
# Out:
#     Age  Sex
# ID
# 1    63    1
# 2    67    1

# %%
df.iloc[0, 0]
# Out:
# 63

# %%
df.iloc[0:2, 0:2]
# Out:
#     Age  Sex
# ID
# 1    63    1
# 2    67    1

# %% [markdown]
# ### selecting certain columns
#
# By using a nested list within square brackets, [[ ]], this ensures that a data frame is returned. In this example we did not retreive the columns in the same order as the original data frame.

# %%
df_new = df[['Sex','Age']]
df_new.head()
# Out:
#     Sex  Age
# ID
# 1     1   63
# 2     1   67
# 3     1   67
# 4     1   37
# 5     0   41

# %% [markdown]
# ### slicing data frames
#
# Next we select only one column, which returns a series. A pandas **series** is a one-dimensional array. In this case we also selected just the first 5 rows.
#
# Remember:
#
# * DataFrame is 2D
# * Series is 1D
#
# This will be important in machine learning because sklearn expects the input data to be a data frame not a series.

# %%
df['Age'][:5]   # this is a series not a data frame
# Out:
# ID
# 1    63
# 2    67
# 3    67
# 4    37
# 5    41
# Name: Age, dtype: int64

# %%
df[['Age']][:5]  # this is a data frame because of the double brackets [[ ]]
# Out:
#     Age
# ID
# 1    63
# 2    67
# 3    67
# 4    37
# 5    41

# %% [markdown]
# ### Selecting rows from a pandas data frame

# %%
df[5:10]
# Out:
#     Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# ID
# 6    56    1    nontypical     120   236    0        0    178      0      0.8
# 7    62    0  asymptomatic     140   268    0        2    160      0      3.6
# 8    57    0  asymptomatic     120   354    0        0    163      1      0.6
# 9    63    1  asymptomatic     130   254    0        2    147      0      1.4
# 10   53    1  asymptomatic     140   203    1        2    155      1      3.1
#
#     Slope   Ca        Thal  AHD
# ID
# 6       1  0.0      normal   No
# 7       3  2.0      normal  Yes
# 8       1  0.0      normal   No
# 9       2  1.0  reversable  Yes
# 10      3  0.0  reversable  Yes

# %%
df[df.Age > 70]
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# ID
# 43    71    0    nontypical     160   302    0        0    162      0
# 104   71    0    nonanginal     110   265    1        2    130      0
# 162   77    1  asymptomatic     125   304    0        2    162      1
# 234   74    0    nontypical     120   269    0        2    121      1
# 258   76    0    nonanginal     140   197    0        1    116      0
# 274   71    0  asymptomatic     112   149    0        0    125      0
#
#      Oldpeak  Slope   Ca    Thal  AHD
# ID
# 43       0.4      1  2.0  normal   No
# 104      0.0      1  1.0  normal   No
# 162      0.0      1  3.0  normal  Yes
# 234      0.2      1  1.0  normal   No
# 258      1.1      2  0.0  normal   No
# 274      1.6      2  0.0  normal   No

# %%
df.sample(frac=0.01)
# Out:
#     Age  Sex   ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# ID
# 62   46    0  nonanginal     142   177    0        2    160      1      1.4
# 86   44    1  nonanginal     140   235    0        2    180      0      0.0
# 23   58    1  nontypical     120   284    0        2    160      0      1.8
#
#     Slope   Ca    Thal  AHD
# ID
# 62      3  0.0  normal   No
# 86      1  0.0  normal   No
# 23      2  0.0  normal  Yes

# %%
df.sample(n=5)
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# ID
# 3     67    1  asymptomatic     120   229    0        2    129      1
# 37    43    1  asymptomatic     120   177    0        2    120      1
# 269   40    1  asymptomatic     152   223    0        0    181      0
# 219   64    0  asymptomatic     130   303    0        0    122      0
# 137   70    1  asymptomatic     145   174    0        0    125      1
#
#      Oldpeak  Slope   Ca        Thal  AHD
# ID
# 3        2.6      2  2.0  reversable  Yes
# 37       2.5      2  0.0  reversable  Yes
# 269      0.0      1  0.0  reversable  Yes
# 219      2.0      2  2.0      normal   No
# 137      2.6      3  0.0  reversable  Yes

# %% [markdown]
# There is much more to pandas than we have covered here, we just covered enough to get started with machine learning.
